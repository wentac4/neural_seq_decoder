# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.9 python3.9-dev python3.9-distutils python3.9-venv
# !curl -sS https://bootstrap.pypa.io/get-pip.py | sudo python3.9
# !sudo update-alternatives --install /usr/bin/python python /usr/bin/python3.9 1
# !sudo update-alternatives --install /usr/bin/python python /usr/bin/python3 2
# !sudo update-alternatives --config python
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,196 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !python3.9 -m venv /content/py39
# !source /content/py39/bin/activate && python --version
# Out:
# Python 3.9.25

# %%
# !source /content/py39/bin/activate && pip install \
torch==1.13.1 hydra-core==1.3.2 hydra-submitit-launcher==1.1.5 \
hydra-optuna-sweeper==1.2.0 numpy==1.25.0 scipy==1.11.1 numba==0.58.1 \
scikit-learn==1.3.2 g2p_en==2.1.0 edit_distance==1.0.6
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 25.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 77.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.5/36.5 MB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 103.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 83.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 54.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 77.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 69.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
dataDir = '/content/drive/MyDrive/NSP/neural_seq_decoder-master/speechPaperRelease_08_20/competitionData'
# %cd /content/drive/MyDrive/NSP/neural_seq_decoder-master
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NSP/neural_seq_decoder-master

# %%
# !source /content/py39/bin/activate && pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/NSP/neural_seq_decoder-master
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for neural_decoder (pyproject.toml) ... done
#   Created wheel for neural_decoder: filename=neural_decoder-0.0.1-0.editable-py3-none-any.whl size=1634 sha256=a72565b4027591884efc7bf2878db8955b0e5705269614f426a9f3b8f436c0dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-slbl6wsy/wheels/00/3c/ff/72083d8a7eb27b793fb75587627f98c9a6312b9ab1b6634196
# Successfully built neural_decoder
# ...

# %% [markdown]
# #Baseline

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/neural_decoder_trainer.py:177: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

def load_pickle_file(filename):
    """Loads data from a pickle file."""
    try:
        with open(filename, 'rb') as f:
            data = pickle.load(f)
        return data
    except Exception as e:
        print(f"Error loading pickle file: {e}")
        return None
# Example usage:
pickle_filename = '/content/drive/MyDrive/NSP/neural_seq_decoder-master/logs/speech_logs/speechBaseline4/trainingStats'
loaded_data = load_pickle_file(pickle_filename)
test_loss = loaded_data['testLoss']
test_cer = loaded_data['testCER']
# Plot the loss and cer over batch
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(test_loss, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(test_cer, label='Test CER')
plt.xlabel('Epoch')
plt.ylabel('CER')
plt.legend()
plt.show()
# Print the loaded data
print("Test Loss:", test_loss)
print("Test CER:", test_cer)

# %% [markdown]
# #lr Related Tuning (0.2 - 0.005 l2 5e-6 n 20000)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_tuning.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #lr Related Tuning (0.1 -  0.02 n 15000 l2 1e-5)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_tuning.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #lr Tuning (0.06-0.005 n 20000 l2 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_tuning.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #lr Tuning (0.06-0.001 n 20000 l2 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_tuning.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.5 - 0.002 m 0.9 l2 1e-5)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.1 - 0.002 m 0.95 l2 1e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.1 - 0.002 m 0.95 l2 1e-6 n 20000)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.002 m 0.99 l2 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.05 - 0.001 m 0.95 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.01 m 0.9 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.05 m 0.9 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.05 m 0.9 5e-6) n 20000

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.2 m 0.9) n 10000

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.1 - 0.1 m 0.95) n 10000

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/ Momentum (0.2 - 0.01 m 0.8 5e-6)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/o Momentum (1 - 1)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_vsgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #SGD w/o Momentum (1 - 0.5)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_vsgd.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 2 len 20)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 4 len 10)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 4 len 10 white noise 1.0)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 4 len 10 white noise 1.5)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 4 len 8 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #White noise (1.2) (cer 0.227 when 1.0)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_white_noise.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time masking (n 4 len 8) w/o white noise

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (mask 2 len 16 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (gaussion mask 2 len 16 sd 0.1 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (gaussion mask 2 len 16 sd 0.5 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Time Masking (gaussion mask 2 len 16 sd 1.0 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Feature Masking (mask 4 len 64 sd 0.0 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_feature_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Feature Masking (mask 4 len 32 sd 0.0 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_feature_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Feature Masking (mask 4 len 32 sd 1.0 white noise 1.2)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_feature_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #TF Masking (T 2 16 F 4 32)

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Sgd (w/ momentum) with augmentation - Similar with adam

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_sgd_with_tm.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...

# %% [markdown]
# #Tuned Adam (-0.002) with augmentation - WORSE

# %%
# !source /content/py39/bin/activate && \
cd /content/drive/MyDrive/NSP/neural_seq_decoder-master && \
python train_model_time_masking.py
# Out:
# /content/py39/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/drive/MyDrive/NSP/neural_seq_decoder-master/src/neural_decoder/augmentations.py:91: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   return self.conv(input, weight=self.weight, groups=self.groups, padding="same")
# ...
